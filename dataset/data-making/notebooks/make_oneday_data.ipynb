# %%
import os
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns
import re
import sklearn


def datetime_range(start, end, delta):
    current = start
    while current <= end:
        yield current
        current += delta
        
def create_time_list(year, month, date):
    dts = [dt.strftime('%Y-%m-%d T%H:%M Z') for dt in
            datetime_range(datetime(year, month, date, 0), datetime(year, month, date, 23, 59), timedelta(minutes=10))]
    return dts

def make_dates(x):
    if len(str(x)) == 2:
        return str(x)
    else:
        return "0" + str(x)

folder_path = "../../../data/accumulated-raf-data"


ob_locations = pd.read_csv('../../../p-poteka-config/observation_point.csv', index_col="Name")

years = ['2019', '2020']
monthes = ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11']
dates = [make_dates(i) for i in range(1, 32)]

cols = ['LON', 'LAT', 'hour-rain', 'AT1', 'RH1', 'SOL', 'WD1', 'WS1']

data_cols = ['hour-rain', 'AT1', 'RH1', 'SOL', 'WD1', 'WS1']

for year in years:
    for month in monthes:
        for date in dates:
            count = 0
            for ob_point in os.listdir(folder_path):
                path = folder_path + f'/{ob_point}/{year}/{month}/{year}-{month}-{date}/data.csv'
                if os.path.exists(path):
                    count += 1
            if count > 30:
                print(f'{year}-{month}-{date} ', count)
                ob_data = []
                ob_names = []
                ob_lon_lat = []
                for ob_point in os.listdir(folder_path):
                    path = folder_path + f'/{ob_point}/{year}/{month}/{year}-{month}-{date}/data.csv'
                    if os.path.exists(path):
                        ob_names.append(ob_point)
                        ob_df = pd.read_csv(path, index_col='Datetime')
                        ob_data.append(ob_df)
                        ob_lon, ob_lat = ob_locations.loc[ob_point, 'LON'], ob_locations.loc[ob_point, 'LAT']
                        ob_lon_lat.append([ob_lon, ob_lat])
                
                time_list = create_time_list(int(year), int(month), int(date))
                
                # Save Folder
                save_folder_path = "../../../data/one_day_data"
                create_folder = [year, month, f'{year}-{month}-{date}']
                for folder_name in create_folder:
                    save_folder_path = save_folder_path + f'/{folder_name}'
                    if not os.path.exists(save_folder_path):
                        os.mkdir(save_folder_path)
                
                for time in time_list:
                    df = pd.DataFrame(index=ob_names, columns=cols)
                    datetime_obj = datetime.strptime(time, '%Y-%m-%d T%H:%M Z')
                    #print(time, datetime_obj.hour, datetime_obj.minute)
                    for i in range(len(ob_data)):
                        data = ob_data[i]
                        ob_name = ob_names[i]
                        ob_point = ob_lon_lat[i]
                        df.loc[ob_name, 'LON'], df.loc[ob_name, 'LAT'] = ob_point
                        for col in data_cols:
                            df.loc[ob_name, col] = data.loc[time, col]
                    #print(df)
                    
                    save_path = save_folder_path + f'/{datetime_obj.hour}-{datetime_obj.minute}.csv'
                    print(save_path)
                    #df.to_csv(save_path)
# Out:
# 2019-10-31  31
# ../../../data/one_day_data/2019/10/2019-10-31/0-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/0-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/0-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/0-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/0-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/0-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/1-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/1-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/1-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/1-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/1-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/1-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/2-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/2-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/2-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/2-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/2-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/2-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/3-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/3-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/3-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/3-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/3-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/3-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/4-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/4-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/4-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/4-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/4-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/4-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/5-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/5-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/5-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/5-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/5-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/5-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/6-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/6-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/6-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/6-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/6-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/6-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/7-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/7-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/7-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/7-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/7-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/7-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/8-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/8-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/8-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/8-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/8-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/8-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/9-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/9-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/9-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/9-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/9-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/9-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/10-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/10-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/10-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/10-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/10-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/10-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/11-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/11-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/11-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/11-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/11-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/11-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/12-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/12-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/12-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/12-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/12-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/12-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/13-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/13-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/13-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/13-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/13-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/13-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/14-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/14-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/14-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/14-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/14-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/14-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/15-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/15-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/15-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/15-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/15-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/15-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/16-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/16-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/16-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/16-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/16-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/16-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/17-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/17-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/17-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/17-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/17-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/17-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/18-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/18-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/18-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/18-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/18-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/18-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/19-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/19-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/19-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/19-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/19-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/19-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/20-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/20-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/20-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/20-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/20-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/20-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/21-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/21-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/21-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/21-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/21-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/21-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/22-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/22-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/22-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/22-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/22-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/22-50.csv
# ../../../data/one_day_data/2019/10/2019-10-31/23-0.csv
# ../../../data/one_day_data/2019/10/2019-10-31/23-10.csv
# ../../../data/one_day_data/2019/10/2019-10-31/23-20.csv
# ../../../data/one_day_data/2019/10/2019-10-31/23-30.csv
# ../../../data/one_day_data/2019/10/2019-10-31/23-40.csv
# ../../../data/one_day_data/2019/10/2019-10-31/23-50.csv
# 2019-11-01  31
# ../../../data/one_day_data/2019/11/2019-11-01/0-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/0-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/0-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/0-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/0-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/0-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/1-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/1-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/1-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/1-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/1-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/1-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/2-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/2-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/2-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/2-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/2-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/2-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/3-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/3-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/3-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/3-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/3-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/3-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/4-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/4-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/4-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/4-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/4-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/4-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/5-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/5-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/5-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/5-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/5-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/5-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/6-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/6-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/6-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/6-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/6-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/6-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/7-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/7-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/7-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/7-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/7-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/7-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/8-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/8-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/8-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/8-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/8-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/8-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/9-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/9-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/9-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/9-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/9-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/9-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/10-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/10-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/10-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/10-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/10-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/10-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/11-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/11-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/11-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/11-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/11-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/11-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/12-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/12-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/12-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/12-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/12-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/12-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/13-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/13-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/13-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/13-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/13-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/13-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/14-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/14-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/14-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/14-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/14-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/14-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/15-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/15-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/15-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/15-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/15-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/15-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/16-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/16-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/16-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/16-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/16-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/16-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/17-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/17-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/17-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/17-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/17-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/17-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/18-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/18-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/18-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/18-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/18-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/18-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/19-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/19-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/19-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/19-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/19-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/19-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/20-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/20-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/20-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/20-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/20-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/20-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/21-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/21-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/21-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/21-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/21-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/21-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/22-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/22-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/22-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/22-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/22-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/22-50.csv
# ../../../data/one_day_data/2019/11/2019-11-01/23-0.csv
# ../../../data/one_day_data/2019/11/2019-11-01/23-10.csv
# ../../../data/one_day_data/2019/11/2019-11-01/23-20.csv
# ../../../data/one_day_data/2019/11/2019-11-01/23-30.csv
# ../../../data/one_day_data/2019/11/2019-11-01/23-40.csv
# ../../../data/one_day_data/2019/11/2019-11-01/23-50.csv
# 2019-11-02  31
# ../../../data/one_day_data/2019/11/2019-11-02/0-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/0-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/0-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/0-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/0-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/0-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/1-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/1-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/1-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/1-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/1-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/1-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/2-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/2-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/2-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/2-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/2-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/2-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/3-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/3-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/3-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/3-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/3-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/3-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/4-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/4-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/4-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/4-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/4-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/4-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/5-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/5-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/5-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/5-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/5-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/5-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/6-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/6-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/6-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/6-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/6-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/6-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/7-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/7-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/7-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/7-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/7-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/7-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/8-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/8-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/8-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/8-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/8-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/8-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/9-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/9-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/9-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/9-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/9-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/9-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/10-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/10-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/10-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/10-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/10-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/10-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/11-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/11-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/11-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/11-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/11-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/11-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/12-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/12-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/12-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/12-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/12-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/12-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/13-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/13-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/13-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/13-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/13-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/13-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/14-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/14-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/14-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/14-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/14-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/14-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/15-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/15-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/15-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/15-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/15-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/15-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/16-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/16-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/16-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/16-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/16-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/16-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/17-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/17-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/17-20.csv
# ../../../data/one_day_data/2019/11/2019-11-02/17-30.csv
# ../../../data/one_day_data/2019/11/2019-11-02/17-40.csv
# ../../../data/one_day_data/2019/11/2019-11-02/17-50.csv
# ../../../data/one_day_data/2019/11/2019-11-02/18-0.csv
# ../../../data/one_day_data/2019/11/2019-11-02/18-10.csv
# ../../../data/one_day_data/2019/11/2019-11-02/18-20.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-b93be9955949> in <module>
#      78                         ob_name = ob_names[i]
#      79                         ob_point = ob_lon_lat[i]
# ---> 80                         df.loc[ob_name, 'LON'], df.loc[ob_name, 'LAT'] = ob_point
#      81                         for col in data_cols:
#      82                             df.loc[ob_name, col] = data.loc[time, col]
#
# ~/anaconda3/envs/p-poteka/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668             key = com.apply_if_callable(key, self.obj)
#     669         indexer = self._get_setitem_indexer(key)
# --> 670         self._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~/anaconda3/envs/p-poteka/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1062             # actually do the set
#    1063             self.obj._consolidate_inplace()
# -> 1064             self.obj._data = self.obj._data.setitem(indexer=indexer, value=value)
#    1065             self.obj._maybe_update_cacher(clear=True)
#    1066
#
# ~/anaconda3/envs/p-poteka/lib/python3.7/site-packages/pandas/core/internals/managers.py in setitem(self, **kwargs)
#     559
#     560     def setitem(self, **kwargs):
# --> 561         return self.apply("setitem", **kwargs)
#     562
#     563     def putmask(self, **kwargs):
#
# ~/anaconda3/envs/p-poteka/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/anaconda3/envs/p-poteka/lib/python3.7/site-packages/pandas/core/internals/blocks.py in setitem(self, indexer, value)
#     916         if transpose:
#     917             values = values.T
# --> 918         block = self.make_block(values)
#     919         return block
#     920
#
# ~/anaconda3/envs/p-poteka/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_block(self, values, placement)
#     271             placement = self.mgr_locs
#     272
# --> 273         return make_block(values, placement=placement, ndim=self.ndim)
#     274
#     275     def make_block_same_class(self, values, placement=None, ndim=None):
#
# ~/anaconda3/envs/p-poteka/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3032     if klass is None:
#    3033         dtype = dtype or values.dtype
# -> 3034         klass = get_block_type(values, dtype)
#    3035
#    3036     elif klass is DatetimeTZBlock and not is_datetime64tz_dtype(values):
#
# ~/anaconda3/envs/p-poteka/lib/python3.7/site-packages/pandas/core/internals/blocks.py in get_block_type(values, dtype)
#    3003     elif is_extension_array_dtype(values):
#    3004         cls = ExtensionBlock
# -> 3005     elif issubclass(vtype, np.floating):
#    3006         cls = FloatBlock
#    3007     elif issubclass(vtype, np.timedelta64):
#
# KeyboardInterrupt:
