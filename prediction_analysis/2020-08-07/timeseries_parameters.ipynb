# %%
import sys

sys.path.append("../")
from utils import time_series_df, time_series_plot

data_root_dir_path = "../../../data/one_day_data/"
year = "2020"
month = "08"
date = "07"
start_time_h = 3
end_time_h = 8

df = time_series_df(data_root_dir_path, year, month, date, start_time_h, end_time_h)
df.tail()

save_fig_dir = "."
time_series_plot(
    df,
    target_cols=["hour-rain", "AT1", "RH1", "WS1", "WD1", "V-Wind", "U-Wind", "PRS"],
    save_fig_dir=save_fig_dir,
    exclude_observation_points=["Vlz-Bagbaguin_00174731"],
)
# Out:
# hour-rain data of CAAP_00174729 has abnormal value.
# PRS data of ASTI_00173457 has 11 zero different values.
# PRS data of Anabu-1B_00181286 has 13 zero different values.
# PRS data of Bayanan-ES_00181283 has 11 zero different values.
# PRS data of C3Bldg_00181284 has 11 zero different values.
# PRS data of CAAP_00174729 has 12 zero different values.
# PRS data of CMuntilupa_00181294 has 14 zero different values.
# PRS data of CentPark_00181288 has 13 zero different values.
# PRS data of E-Library_00181274 has 11 zero different values.
# PRS data of LP-DrFelimon_00174733 has 11 zero different values.
# PRS data of LP-Elias_00174724 has 14 zero different values.
# PRS data of LP-SciHS_00174726 has 11 zero different values.
# PRS data of MM-Balut_00174728 has 14 zero different values.
# PRS data of MM-Catmon_00174723 has 15 zero different values.
# PRS data of MM-Libertad_00181289 has 13 zero different values.
# PRS data of NAMRIA_00181292 has 13 zero different values.
# PRS data of NBP_00181293 has 11 zero different values.
# PRS data of RAVE_00181290 has 12 zero different values.
# PRS data of Sinegue_00181300 has 14 zero different values.
# PRS data of TUP-Taguig_00181272 has 11 zero different values.
# PRS data of Xavier-Sch_00181285 has 14 zero different values.
