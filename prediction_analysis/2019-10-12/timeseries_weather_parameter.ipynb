# %%
import sys

sys.path.append("../")
from utils import time_series_df, time_series_plot

data_root_dir_path = "../../../data/one_day_data/"
year = "2019"
month = "10"
date = "12"
start_time_h = 7
end_time_h = 11

df = time_series_df(data_root_dir_path, year, month, date, start_time_h, end_time_h)
df.tail()

save_fig_dir = "."
time_series_plot(
    df,
    target_cols=["hour-rain", "AT1", "RH1", "WS1", "WD1", "V-Wind", "U-Wind", "PRS"],
    save_fig_dir=save_fig_dir,
    exclude_observation_points=["Vlz-Bagbaguin_00174731"],
)
# Out:
# WS1 data of RAVE_00181290 has 11 zero different values.
# V-Wind data of RAVE_00181290 has 11 zero different values.
# PRS data of MM-EFCOS_00173456 has 10 zero different values.
# PRS data of MM-Libertad_00181289 has 10 zero different values.
# PRS data of MM-Tapayan_00173458 has 11 zero different values.
# PRS data of NAMRIA_00181292 has 11 zero different values.
# PRS data of RED_00174732 has 14 zero different values.
